# %%
# リスト（array）の作成
array = [
    "月曜日は晴れです",        # index 0
    "火曜日は雨です",          # index 1
    "水曜日は晴れです",        # index 2 (ここを取り出す)
    "木曜日は晴れです",        # index 3
    "金曜日は曇りです",        # index 4
    "土曜日は曇りのち雨です",  # index 5
    "日曜日は雷雨です"         # index 6
]

# 水曜日の予報（インデックス2番目）を取り出して出力
wednesday_forecast = array[2]

print(wednesday_forecast)

# ディクショナリ（dictionary）の作成
dictionary = {
    "mon": "晴れ",
    "tue": "雨",
    "wed": "晴れ",
    "thu": "晴れ",
    "fri": "曇り",
    "sat": "曇りのち雨",
    "sun": "雷雨"
}

# 水曜日の天気予報（キー "wed"）を取り出して出力
print(dictionary["wed"])
# Out:
# 水曜日は晴れです
# 晴れ
